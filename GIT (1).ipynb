# %% [markdown]
# ***GIT***
#
# Git is a DevOps tool used for source code management. It is a free and open-source version control system used to handle small to very large projects efficiently. Git is used to tracking changes in the source code, enabling multiple developers to work together on non-linear development

# %% [markdown]
# ***GIT Strategy***
# ![git startegy.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ***Install GIT in RHEL/CENTOS***

# %%
sudo yum install git -y

# %% [markdown]
# ***Check GIT version***

# %%
git --version

# %% [markdown]
# ***Create a git repository locally***
#
# First create a directory for git & switch to that directory
#
# Create a local repository
#
# Now check local repository files including hidden

# %%
mkdir git_practice && cd git_practice

# %%
git init .

# %%
ls -a

# %% [markdown]
# ***Steps to commit a file***
#
# Go to git_practice directory & create a file touch f1
#
# Check status of git git status
#
# Add that file to git git add f1
#
# Commit the file with commit message git commit -m <”commit message”><”file name”>
# (git commit -m “This is my first commit” f1)
#
# Check file commit details git log

# %%
touch f1

# %%
git status

# %%
git add f1

# %%
git commit -m 'this is my first message' f1

# %%
git log

# %% [markdown]
# Now commit the second file “f2” > Follow the same process above.
#
# Execute git log to check number of commits

# %% [markdown]
# *** Add repository ***
#
# git remote add origin repository url

# %%
git remote add origin <git hub repository url>

# %% [markdown]
# ***Check git branch***

# %%
git branch

# %% [markdown]
# ***Push files to git repo***
#
# (it will ask for username and password - don’t give password, provide token)

# %%
git push -u origin master

# %% [markdown]
# ***GIT BRANCHES***

# %% [markdown]
# ***Check git branch***

# %%
git branch

# %% [markdown]
# ***Create a new branch***

# %%
git branch <branch name!>

# %% [markdown]
# ***Switch to a branch***

# %%
git checkout <branch name!>

# %% [markdown]
# ***Add files to new branch and commit those files***

# %%
git add <file name!> && git commit -m <”commit message”!><file name!>

# %% [markdown]
# ***Push branch to GIT central repository***

# %%
git push -u origin master <branch name!>

# %% [markdown]
# ***Shortcut method for creating a branch and switching to that branch***

# %%
git checkout -b <branch name!>

# %% [markdown]
# ***Change branch name***

# %%
git branch -m <old branch name!> <new branch name!>

# %% [markdown]
# ***Update local repository to the newest commit***

# %%
git pull

# %% [markdown]
# ***Pull changes from remote repository***

# %%
git pull origin <branch name!>

# %% [markdown]
# ***Delete a branch***

# %%
git branch -D <branch name!>

# %% [markdown]
# ***Delete a remote branch***

# %%
git push origin --delete <branchname!>

# %% [markdown]
# ***Rename a Branch***

# %%
git branch -m <old branch name!> <new branch name!>

# %% [markdown]
# ***Rename a remote Branch***

# %%
git push origin :<old branch name!> <new branch name!>
